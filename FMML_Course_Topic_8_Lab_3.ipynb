# %% [markdown]
# <a href="https://colab.research.google.com/github/SILENTQUEEN123/Fmml/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-11 10:19:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   123MB/s    in 0.6s
#
# 2024-04-11 10:19:07 (123 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39956  1708.02872v1  Recently, cloud storage and processing have be...    cs
# 30860  1801.06769v1  Rain removal from a single image is a challeng...    cs
# 34703  1710.04142v1  In past few years, several data-sets have been...    cs
# 18618   1106.1853v3  The human intelligence lies in the algorithm, ...    cs
# 31315  1802.10508v1  Quantitative analysis of brain tumors is criti...    cs
# ...             ...                                                ...   ...
# 21849   1401.2771v1  Recently, a number of mostly $\ell_1$-norm reg...  stat
# 2682   1705.09786v3  New types of machine learning hardware in deve...    cs
# 18141  cs/0407008v1  Learning to respond to voice-text input involv...    cs
# 6753   1705.10194v1  We propose a novel adaptive approximation appr...  stat
# 26663  1611.05842v1  We present a survey on maritime object detecti...    cs
#
#                                                    title  year  \
# 39956  Privacy Preserving Face Retrieval in the Cloud...  2017
# 30860  Deep joint rain and haze removal from single i...  2018
# 34703  Bollywood Movie Corpus for Text, Images and Vi...  2017
# 18618  Intelligent decision: towards interpreting the...  2011
# 31315  Brain Tumor Segmentation and Radiomics Surviva...  2018
# ...                                                  ...   ...
# 21849  A variational Bayes framework for sparse adapt...  2014
# 2682   AMPNet: Asynchronous Model-Parallel Training f...  2017
# 18141  Autogenic Training With Natural Language Proce...  2004
# 6753   Adaptive Classification for Prediction Under a...  2017
# 26663  Video Processing from Electro-optical Sensors ...  2016
#
#                                                 keywords
# 39956  [processing, automatically, collection, provid...
# 30860  [challenge, convolutional, correspond, frequen...
# 34703  [detecting, challenges, wikipedia, bollywood, ...
# 18618  [intelligence, algorithm, algorithm, classific...
# 31315  [quantitative, segmentation, consuming, subjec...
# ...                                                  ...
# 21849  [regularized, deterministic, algorithms, emphs...
# 2682   [development, revolutionizing, frameworks, alg...
# 18141  [understanding, communicate, experience, cogni...
# 6753   [approximation, constrained, prediction, ident...
# 26663  [detection, approaches, essential, development...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39956    [processing, automatically, collection, provid...
# 30860    [challenge, convolutional, correspond, frequen...
# 34703    [detecting, challenges, wikipedia, bollywood, ...
# 18618    [intelligence, algorithm, algorithm, classific...
# 31315    [quantitative, segmentation, consuming, subjec...
#                                ...
# 22596    [dimensional, processes, effectivewell, charac...
# 22011    [multivariate, correlated, likelihood, multiva...
# 17919    [algorithms, statistically, selection, techniq...
# 27947    [multiview, resolution, reconstruction, resamp...
# 5204     [classification, assumption, stationary, distr...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8861 words.
# Out of those 4607 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2cff4c26-133d-440d-91cf-841b0161e734" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cff4c26-133d-440d-91cf-841b0161e734")) {                    Plotly.newPlot(                        "2cff4c26-133d-440d-91cf-841b0161e734",                        [{"x":["retrieval","simultaneously","computing","collection","processing","protected","meanwhile","providers","automatically","copyright","preserving","resources","experimental","successfully","accumulation","increasing","transform","optimized","therefore","experiments","qualitative","propagation","represent","component","convolutional","quantitative","background","challenge","perspective","specifically","outperforms","synthetic","information","correspond","parameters","frequency","detecting","corresponding","performing","adjectives","challenges","extracted","wikipedia","preliminary","following","centrality","available","relations","referenced","furthermore","discussion","detection","definitions","robustness","originated","interpreting","comparison","understanding","intelligent","mechanism","seamlessly","subsequence","efficient","algorithms","algorithm","classification","interpret","demonstrate","introduce","introduced","intelligence","describing","challenging","subjective","enhancing","carefully","subregions","prediction","consuming","performance","automatic","regressor","multilayer","correlation","imbalances","coefficient","architecture","extensive","developing","overfitting","radiomics","augmentation","perceptrons","validation","contribution","segmentation","responses","controlling","principle","knowledge","incorporate","explained","minimization","inference","framework","smoothing","pretreatment","maximally","theoretical","suggested","transductive","different","individual","approaching","illustrate","sensitivity","dependent","applications","maximizing","establish","recognition","technique","uncompressed","localization","evaluated","outperform","relationship","coherence","supervisory","embedding","supervised","aggregation","implementation","frequently","nonlinear","procedure","occurring","structure","allocation","dirichlet","neighborhood","approximate","corresponds","intricate","extending","interpretability","conditional","optimization","controller","expectation","reinforcement","optimizing","prominent","likelihood","stochastic","convergence","sensitive","application","extensively","estimator","extensions","catastrophic","restrictive","reachable","optimally","including","assumptions","especially","theoretically","probabilistic","unavoidable","relationships","heuristic","iteration","scenarios","empirical","principled","increasingly","comparing","assumption","strategies","experiment","simulations","generally","clustering","extension","resonance","observations","incomplete","functional","illustrations","nonparametric","initialize","activation","considered","connectives","condition","soundness","consequence","researchers"],"y":[92,98,124,77,282,3,24,4,180,2,57,65,401,86,5,104,63,40,175,626,59,63,111,113,379,68,79,159,73,144,262,144,679,29,247,56,77,124,76,5,103,127,22,48,76,2,304,70,5,154,30,322,16,88,6,17,134,162,52,109,10,6,450,625,834,524,23,587,341,139,90,30,265,25,20,23,1,217,30,875,214,7,14,79,3,17,261,162,61,15,2,28,5,45,62,177,26,19,59,365,52,16,58,211,554,15,0,7,158,23,4,750,131,11,80,34,77,432,22,48,365,255,3,63,149,99,60,25,5,93,189,24,145,35,54,130,13,322,27,18,14,113,16,4,36,24,98,313,17,29,111,52,17,59,131,122,65,238,37,27,45,5,4,4,26,235,64,115,36,164,2,79,55,40,92,142,24,54,73,68,100,76,42,68,160,84,24,74,28,39,0,18,7,35,144,4,45,3,14,69],"type":"bar"},{"x":["retrieval","simultaneously","computing","collection","processing","protected","meanwhile","providers"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4607,), (4607, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Rose</span> <span style=''>Trees</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ubiquitous</span> <span style=''>in</span> <span style=''>data</span> <span style=''>across</span> <span style=''>many</span> <span style=''>domains</span> <span style=''>There</span> <span style=''>are</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frequently</span> <span style=''>used</span> <span style=''>by</span> <span style=''>domain</span> <span style=''>experts</span> <span style=''>which</span> <span style=''>strive</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>However</span> <span style=''>most</span> <span style=''>of</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>limit</span> <span style=''>discoverable</span> <span style='background-color:rgba(0, 255, 0, 0.43999999999999995);'>hierarchies</span> <span style=''>to</span> <span style=''>those</span> <span style=''>with</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>branching</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>limitation</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convenient</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>undesirable</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>can</span> <span style=''>produce</span> <span style=''>trees</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>branching</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>at</span> <span style=''>each</span> <span style=''>node</span> <span style=''>known</span> <span style=''>as</span> <span style=''>rose</span> <span style=''>trees</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style=''>these</span> <span style=''>trees</span> <span style=''>as</span> <span style=''>mixtures</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3125);'>partitions</span> <span style=''>of</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>and</span> <span style=''>use</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>greedy</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>agglomerative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>rose</span> <span style=''>trees</span> <span style=''>which</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Speeding</span> <span style=''>Up</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimizations</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>(LVGGM)</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>superposition</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>speed</span> <span style=''>up</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>plus</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>sparsity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>based</span> <span style=''>on</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>hard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thresholding</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>it</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>magnitude</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>the</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxation</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>LVGGM</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>linearly</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>sparse</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computing</span> <span style=''>Fair</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Classifiers</span> <span style=''>and</span> <span style=''>rating</span> <span style=''>scores</span> <span style=''>are</span> <span style=''>prone</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implicitly</span> <span style=''>codifying</span> <span style=''>biases</span> <span style=''>which</span> <span style=''>may</span> <span style=''>be</span> <span style=''>present</span> <span style=''>in</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>against</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>protected</span> <span style=''>classes</span> <span style=''>(ie</span> <span style=''>age</span> <span style=''>gender</span> <span style=''>or</span> <span style=''>race)</span> <span style=''>So</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.41509433962264153);'>understand</span> <span style=''>how</span> <span style=''>to</span> <span style=''>design</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>scores</span> <span style=''>that</span> <span style=''>prevent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>develops</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>designing</span> <span style=''>accurate</span> <span style=''>but</span> <span style=''>fair</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>(SVMs)</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>imposes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3880597014925373);'>constraint</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6347826086956522);'>covariance</span> <span style=''>matrices</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioned</span> <span style=''>on</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>protected</span> <span style=''>class</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5111111111111111);'>nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quadratic</span> <span style='background-color:rgba(0, 255, 0, 0.3880597014925373);'>constraint</span> <span style=''>in</span> <span style=''>the</span> <span style=''>SVM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>We</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>fair</span> <span style=''>linear</span> <span style=''>and</span> <span style=''>kernel</span> <span style=''>SVMs</span> <span style=''>which</span> <span style=''>solve</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibration</span> <span style=''>for</span> <span style=''>forensic</span> <span style=''>evidence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reporting</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>solution</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>forensic</span> <span style=''>speaker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>where</span> <span style=''>there</span> <span style=''>may</span> <span style=''>be</span> <span style=''>very</span> <span style=''>little</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>background</span> <span style=''>material</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>score</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>We</span> <span style=''>work</span> <span style=''>within</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>paradigm</span> <span style=''>of</span> <span style=''>evidence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reporting</span> <span style=''>and</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>results</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>ratio</span> <span style=''>as</span> <span style=''>the</span> <span style=''>vehicle</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reporting</span> <span style=''>weight</span> <span style=''>of</span> <span style=''>evidence</span> <span style=''>We</span> <span style=''>show</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reporting</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>ratio</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>does</span> <span style=''>not</span> <span style=''>solve</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>Our</span> <span style=''>solution</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experimentally</span> <span style=''>exercised</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>forensic</span> <span style=''>scenario</span> <span style=''>using</span> <span style=''>NIST</span> <span style=''>SRE12</span> <span style=''>scores</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrates</span> <span style=''>a</span> <span style=''>clear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>for</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>plugin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibration</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1303106033559443)
# 	automatic (0.07640128525526597)
# 	information (0.24241342377722241)
# 	representation (0.13602284898250624)
# 	architecture (0.09318100678329168)
# 	experimental (0.14316315601570867)
# 	detection (0.11495894323455909)
# 	different (0.26776151374509105)
# 	recognition (0.1303106033559443)
# 	convolutional (0.135308818279186)
#
# Some Statistics words are:
# 	likelihood (0.10455227613806903)
# 	variables (0.1310655327663832)
# 	stochastic (0.1345672836418209)
# 	theoretical (0.14657328664332167)
# 	statistical (0.15407703851925963)
# 	estimation (0.17858929464732365)
# 	inference (0.1905952976488244)
# 	distribution (0.18959479739869936)
# 	dimensional (0.1965982991495748)
# 	regression (0.18209104552276137)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="983441fd-99f0-4381-a2ae-7d5f03477dc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("983441fd-99f0-4381-a2ae-7d5f03477dc9")) {                    Plotly.newPlot(                        "983441fd-99f0-4381-a2ae-7d5f03477dc9",                        [{"x":["retrieval","simultaneously","computing","collection","processing","protected","meanwhile","providers","automatically","copyright","preserving","resources","experimental","successfully","accumulation","increasing","transform","optimized","therefore","experiments","qualitative","propagation","represent","component","convolutional","quantitative","background","challenge","perspective","specifically","outperforms","synthetic","information","correspond","parameters","frequency","detecting","corresponding","performing","adjectives","challenges","extracted","wikipedia","preliminary","following","centrality","available","relations","referenced","furthermore","discussion","detection","definitions","robustness","originated","interpreting","comparison","understanding","intelligent","mechanism","seamlessly","subsequence","efficient","algorithms","algorithm","classification","interpret","demonstrate","introduce","introduced","intelligence","describing","challenging","subjective","enhancing","carefully","subregions","prediction","consuming","performance","automatic","regressor","multilayer","correlation","imbalances","coefficient","architecture","extensive","developing","overfitting","radiomics","augmentation","perceptrons","validation","contribution","segmentation","responses","controlling","principle","knowledge","incorporate","explained","minimization","inference","framework","smoothing","pretreatment","maximally","theoretical","suggested","transductive","different","individual","approaching","illustrate","sensitivity","dependent","applications","maximizing","establish","recognition","technique","uncompressed","localization","evaluated","outperform","relationship","coherence","supervisory","embedding","supervised","aggregation","implementation","frequently","nonlinear","procedure","occurring","structure","allocation","dirichlet","neighborhood","approximate","corresponds","intricate","extending","interpretability","conditional","optimization","controller","expectation","reinforcement","optimizing","prominent","likelihood","stochastic","convergence","sensitive","application","extensively","estimator","extensions","catastrophic","restrictive","reachable","optimally","including","assumptions","especially","theoretically","probabilistic","unavoidable","relationships","heuristic","iteration","scenarios","empirical","principled","increasingly","comparing","assumption","strategies","experiment","simulations","generally","clustering","extension","resonance","observations","incomplete","functional","illustrations","nonparametric","initialize","activation","considered","connectives","condition","soundness","consequence","researchers","involving","nonmonotonic","previously","expansion","rationality","specialized","established","complexity","shrinking","computational","important","liblinear","breakthrough","selection","decomposition","presented","improvement","accelerated","algorithmic","adaptation","objective","developed","frequencies","criterion","magnitude","calibrated","intrinsic","arbitrary","forecasters","approachability","calibration","highlights","blackwells","geometric","connection","existence","structured","functions","significant","variational","computationally","tractable","programming","management","attributes","implement","supported","accessing","development","designing","multilingual","requirements","respectively","dictionary","deploying","construction","classifiers","represe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	pretreatment
# 	illustrations
# 	liblinear
# 	complication
# 	reparametrizations
# 	asymptotics
# 	functoriality
# 	diagnostics
# 	transformative
# 	covariates
# 	delivering
# 	periodicity
# 	spectrogram
# 	archetypes
# 	unavoidably
# 	regressions
# 	traintest
# 	tsybakovs
# 	homomorphic
# 	penalised
# Some words which never appear in Statistics papers:
# 	copyright
# 	adjectives
# 	wikipedia
# 	referenced
# 	subsequence
# 	radiomics
# 	uncompressed
# 	reachable
# 	connectives
# 	nonmonotonic
# 	observers
# 	paragraphs
# 	characters
# 	reservoirs
# 	delineate
# 	taxonomies
# 	syntactic
# 	organising
# 	automaton
# 	hindering

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065885887727259e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
